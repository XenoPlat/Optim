# %% [markdown]
# # Практическое задание к Уроку 1. Вводный

# %% [markdown]
# В проектируемой локальной сети есть заданное количество компьютеров. Есть расстояния от каждого компьютера до сервера и до остальных компьютеров. Маршрутизаторы соединяются с сервером через оптоволокно стоимостью 12 р/м, а компьютеры - с маршрутизаторами соединяются через витую пару стоимостью 30 р/м. Каждый маршрутизатор имеет 8 портов для витой пары и один оптический порт. Сервер имеет неограниченное число оптических портов и портов для витой пары. Компьютер может соединяться с сервером напрямую или через маршрутизатор. 1. Построить ЦФ для расчёта стоимости оборудования ЛВС в общем виде. Учесть стоимость маршрутизатора, обоснованность его установки.

# %% [markdown]
# __1) Компьютеры соединяются по витой паре, без маршрутизатора:__
# $$f(X) = \displaystyle\sum_{i=1}^{n}{l_i}*price:$$<br>
# ${l_i}$ расстояние от компьтера до сервера<br>
# price - цена витой пары<br>
# n - количество компьютеров

# %% [markdown]
# __2) Компьютеры соединяются по витой паре через маршрутизатор:__
#
# для N количества маршрутизаторов
# $$f(X) = \displaystyle\sum_{j=1}^{N}{L_j}*price_o+N*price_m+\displaystyle\sum_{i=1}^{n}{L_i}*price$$:<br>
# l- растояние от маршрутизатора до сервера<br>
# ${L_i}$ - расстояние от компьтера до маршрутизатора<br>
# ${L_j}$ - расстояние от маршрутизатора до сервера<br>
# price_o ЦО- цена оптической пары<br>
# price_m - цена маршрутизатора<br>
# price - цена витой пары<br>
# n - количество компьютеров<br>
# N - количество маршрутизаторов

# %% [markdown]
# __2. Построить поверхность стоимости от сумм расстояний для конкретного примера. Количество компьютеров — больше двух, располагаются не на одной линии в одной четверти относительно сервера.*__
