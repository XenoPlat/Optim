# %% [markdown]
# # Урок 2. Непрерывность, гладкость и сходимость ЦФ. Дискретные ЦФ.

# %% [markdown]
# __Задача про щедрого директора, машину и закупку оборудования:__

# %% [markdown]
# __1) Составить ЦФ для этой задачи, выбрать критерий оптимальности__<br>
#
# Пусть __i__ будет номером позиции закупаемого товара; при этом $1 \leqslant i \leqslant 2 000$<br>
# Пусть __m__ будет весом товара по конкретной позиции; при этом $1 \leqslant {m_i} \leqslant 150$ <br>
# Пусть __р__ будет ценой товара по конкретной позиции; при этом $100 \leqslant p_i \leqslant 5 000$<br>
#
# Т.к. условия задачи не подразумевают жесткие ограничения по бюджету, то она сводится к нахождению членов множества X (и их числа), которое состоит из сумм таких ${x_{imp}}$, которые обеспечивают разрешенную максимальную загрузку машины:<br>
#
# $$f(x) = \displaystyle\sum_{i=1, m = 1, p = 100}^{i = 2000, m = 150, p = 5000}{x_{imp}} \in X \Leftrightarrow \displaystyle\sum_{m=1}^{150}{x_m} = 200$$ <br>
#
# __2) Предложить алгоритм решения задачи__<br>
#
# Задача из области комбинаторики, как я понимаю. Необходимо через циклы, с соблюдением граничных условий и шагов по каждому параметру, выявить все возможные варианты, которые дают максимальный совокупный вес, равный 200 кг. После чего можно сделать датасет с сортировкой от наименьшей совокупной стоимости товаров к наибольшей, по каждому найденому варианту.

# %% [markdown]
# __1) Составить ЦФ, записать ограничения и функцию Лагранжа для решения этой задачи.__

# %% [markdown]
# Пусть $n_1$ будет количеством производимых покрышек<br>
#
# Пусть $n_2$ будет количеством производимых лодок<br>
#
# Тогда ЦФ и КО: $$F = 7000\cdot n_1 + 12000 \cdot n_2\; -> {max}$$<br>

# %% [markdown]
# Ограничения:<br>
#
# $$ заготучасток: 2\cdot n_1 + 6 \cdot n_2 \leq 14$$<br>
# $$обработка: 4\cdot n_1 + 3 \cdot n_2 \leq 10$$<br>
# $$сборка: 2 \cdot n_2 \leq 8 $$

# %% [markdown]
# Тогда функция Лагранжа будет иметь следующий вид:<br>
#
# $$L(n_1,n_2,λ_1,λ_2,λ_3)=7000\cdot n_1+12000\cdot n_2+λ_1(2\cdot n_1+6\cdot n_2−14)+λ_2(4\cdot n_1+3\cdot n_2−10)+λ_3(2\cdot n_2-8)$$<br>

# %% [markdown]
# __2) Разработать оптимальный производственный план предприятия.__

# %% [markdown]
# Для решения этой задачи необходимо найти экстремумы функции Лагранжа. Для этого требуется построить систему уравнений из частных производных (числом 5 штук) и найти решения для этих уравнений. Но на этом мой мозг вскипел.
